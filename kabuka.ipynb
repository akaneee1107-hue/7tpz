# %% [markdown]
# <a href="https://colab.research.google.com/github/akaneee1107-hue/7tpz/blob/main/kabuka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Excelファイルの読み込み
df = pd.read_excel('/content/year_nikei.xlsx')

# データの最初の5行を確認
df.head()

df.to_csv('/content/year_nikei.csv', index=False)

# %%
import pandas as pd

# CSVファイルの読み込み
df = pd.read_csv('/content/year_nikei.csv')

# データの先頭5行を確認
df.head()
# Out:
#    year    kabuka
# 0  1991  22983.77
# 1  1992  16924.95
# 2  1993  17417.24
# 3  1994  19723.06
# 4  1995  19868.15
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_7['year'].plot(kind='hist', bins=20, title='year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_8['kabuka'].plot(kind='hist', bins=20, title='kabuka')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_9.plot(kind='scatter', x='year', y='kabuka', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
# ...

# %%
import pandas as pd

# CSVファイルの読み込み
df = pd.read_csv('/content/afghan (1).csv')

# データの先頭5行を確認
df.head()
# Out:
#   province      district  village.id  age  educ.years  employed        income  \
# 0    Logar  Baraki Barak          80   26          10         0  2,001-10,000
# 1    Logar  Baraki Barak          80   49           3         1  2,001-10,000
# 2    Logar  Baraki Barak          80   60           0         1  2,001-10,000
# 3    Logar  Baraki Barak          80   34          14         1  2,001-10,000
# 4    Logar  Baraki Barak          80   21          12         1  2,001-10,000
#
#    violent.exp.ISAF  violent.exp.taliban list.group  list.response
# 0               0.0                  0.0    control              0
# 1               0.0                  0.0    control              1
# 2               1.0                  0.0    control              1
# 3               0.0                  0.0       ISAF              3
# 4               0.0                  0.0       ISAF              3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/akaneee1107-hue/7tpz/blob/main/Colab_%E3%81%B8%E3%82%88%E3%81%86%E3%81%93%E3%81%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/data2.csv")

df.head()
# Out:
#    shotesuto  kimatsu  sleep method
# 0        4.2       67    7.2    bus
# 1        7.2       71    7.9   bike
# 2        0.0       19    5.3    bus
# 3        3.0       35    6.8   walk
# 4        1.5       35    7.5   walk
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['shotesuto'].plot(kind='hist', bins=20, title='shotesuto')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['kimatsu'].plot(kind='hist', bins=20, title='kimatsu')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['sleep'].plot(kind='hist', bins=20, title='sleep')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf

#precision 3
#matplotlib inline

# %%
df = pd.read_csv('/content/data2.csv')
n = len(df)
print(n)
df.head()
# Out:
# 20
#    shotesuto  kimatsu  sleep method
# 0        4.2       67    7.2    bus
# 1        7.2       71    7.9   bike
# 2        0.0       19    5.3    bus
# 3        3.0       35    6.8   walk
# 4        1.5       35    7.5   walk

# %%
x = np.array(df['shotesuto'])
y = np.array(df['kimatsu'])
p = 1

# %%
poly_fit = np.polyfit(x, y, 1)
poly_1d = np.poly1d(poly_fit)
xs = np.linspace(x.min(), x.max())
ys = poly_1d(xs)

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111)
ax.set_xlabel('shotesuto')
ax.set_ylabel('kimatsu')
ax.plot(xs, ys, color='gray',
        label=f'{poly_fit[1]:.2f}+{poly_fit[0]:.2f}x')
ax.scatter(x, y)
ax.legend()

plt.show()

# %%
formula = 'kimatsu ~ shotesuto'
result = smf.ols(formula, df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                kimatsu   R-squared:                       0.676
# Model:                            OLS   Adj. R-squared:                  0.658
# Method:                 Least Squares   F-statistic:                     37.61
# Date:                Tue, 11 Nov 2025   Prob (F-statistic):           8.59e-06
# Time:                        05:24:37   Log-Likelihood:                -76.325
# No. Observations:                  20   AIC:                             156.7
# Df Residuals:                      18   BIC:                             158.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.6995      4.714      5.028      0.000      13.796      33.603
# ...
